# %%
import torch
import math

import matplotlib.pyplot as plt
import matplotlib

from timeit import default_timer
import h5py
from matplotlib.animation import FuncAnimation

# %% [markdown]
# In this code, dataset for the 2-d Navier-Stokes equation for viscous, incompressible fluid in vorticity form is generated. The equation is given as:
# \begin{equation}
# \frac{\partial w}{\partial t} + u \cdot \nabla w = \nu \Delta w + f, \qquad x \in (0,1)^2, t \in (0,T]
# \end{equation}
# $$ \nabla \cdot u = 0, \qquad x \in (0,1)^2, t \in [0,T]$$
# $$ w(x,0) = w_0(x), $$
#
# where $u$ is the velocity field, $ w = \nabla \times u $ is the vorticity, $\nu$ is the viscocity coefficient, $f$ is the forcing term and $w_0$ is the initial vorticity. The forcing term in this code is:
# $$f(x, y) = 0.1 \left[ \sin\left(2\pi(x + y)\right) + \cos\left(2\pi(x + y)\right) \right],$$
#
# and the viscosity $\nu = 1e^{-3}$.
#
# Access to the original code can be obtained  at https://github.com/ixScience/fourier_neural_operator/blob/master/data_generation/navier_stokes/ns_2d.py. The code below is updated, as most of the commands used are deprecated.

# %%
class GaussianRF(object):

    def __init__(self, dim, size, alpha=2, tau=3, sigma=None, boundary="periodic", device=None):

        self.dim = dim
        self.device = device

        if sigma is None:
            sigma = tau**(0.5*(2*alpha - self.dim))

        k_max = size//2

        if dim == 1:    
            k = torch.cat((torch.arange(start=0, end=k_max, step=1, device=device), \
                           torch.arange(start=-k_max, end=0, step=1, device=device)), 0)

            self.sqrt_eig = size*math.sqrt(2.0)*sigma*((4*(math.pi**2)*(k**2) + tau**2)**(-alpha/2.0))
            self.sqrt_eig[0] = 0.0

        elif dim == 2:
            wavenumers = torch.cat((torch.arange(start=0, end=k_max, step=1, device=device), \
                                    torch.arange(start=-k_max, end=0, step=1, device=device)), 0).repeat(size,1)

            k_x = wavenumers.transpose(0,1)
            k_y = wavenumers

            self.sqrt_eig = (size**2)*math.sqrt(2.0)*sigma*((4*(math.pi**2)*(k_x**2 + k_y**2) + tau**2)**(-alpha/2.0))
            self.sqrt_eig[0,0] = 0.0

        elif dim == 3:
            wavenumers = torch.cat((torch.arange(start=0, end=k_max, step=1, device=device), \
                                    torch.arange(start=-k_max, end=0, step=1, device=device)), 0).repeat(size,size,1)

            k_x = wavenumers.transpose(1,2)
            k_y = wavenumers
            k_z = wavenumers.transpose(0,2)

            self.sqrt_eig = (size**3)*math.sqrt(2.0)*sigma*((4*(math.pi**2)*(k_x**2 + k_y**2 + k_z**2) + tau**2)**(-alpha/2.0))
            self.sqrt_eig[0,0,0] = 0.0

        self.size = []
        for j in range(self.dim):
            self.size.append(size)

        self.size = tuple(self.size)

    def sample(self, N):

        real = torch.randn(N, *self.size, device=self.device)
        imag = torch.randn(N, *self.size, device=self.device)
        coeff = torch.complex(real, imag)

        coeff = self.sqrt_eig * coeff

        u = torch.fft.ifft(coeff, dim=self.dim, norm="backward").real

        return u

# %%
#w0: initial vorticity
#f: forcing term
#visc: viscosity (1/Re)
#T: final time
#delta_t: internal time-step for solve (descrease if blow-up)
#record_steps: number of in-time snapshots to record
def navier_stokes_2d(w0, f, visc, T, delta_t=1e-4, record_steps=1):

    #Grid size - must be power of 2
    N = w0.size()[-1]

    #Maximum frequency
    k_max = math.floor(N/2.0)

    #Number of steps to final time
    steps = math.ceil(T/delta_t)

    #Initial vorticity to Fourier space
    w_h = torch.fft.fft2(w0)

    #Forcing to Fourier space
    f_h = torch.fft.fft2(f)

    #If same forcing for the whole batch
    if len(f_h.size()) < len(w_h.size()):
        f_h = torch.unsqueeze(f_h, 0)

    #Record solution every this number of steps
    record_time = math.floor(steps/record_steps)

    #Wavenumbers in y-direction
    k_y = torch.cat((torch.arange(start=0, end=k_max, step=1, device=w0.device), torch.arange(start=-k_max, end=0, step=1, device=w0.device)), 0).repeat(N,1)
    #Wavenumbers in x-direction
    k_x = k_y.transpose(0,1)
    #Negative Laplacian in Fourier space
    lap = 4*(math.pi**2)*(k_x**2 + k_y**2)
    lap[0,0] = 1.0
    lap = lap.to(dtype=w_h.dtype, device=w_h.device)
    lap = lap.unsqueeze(0)
    #Dealiasing mask
    dealias = torch.unsqueeze(torch.logical_and(torch.abs(k_y) <= (2.0/3.0)*k_max, torch.abs(k_x) <= (2.0/3.0)*k_max).float(), 0)


    #Saving solution and time
    sol = torch.zeros(*w0.size(), record_steps, device=w0.device)
    sol_t = torch.zeros(record_steps, device=w0.device)

    #Record counter
    c = 0
    #Physical time
    t = 0.0
    for j in range(steps):
        #Stream function in Fourier space: solve Poisson equation
        #psi_h = w_h.clone()
        psi_h = w_h / lap

        #Velocity field in x-direction = psi_y
        q_h = 1j * 2 * math.pi * k_y * psi_h
        q = torch.fft.ifft2(q_h).real

        #Velocity field in y-direction = -psi_x
        v_h = -1j * 2 * math.pi * k_x * psi_h
        v = torch.fft.ifft2(v_h).real

        #Partial x of vorticity
        w_x_h = 1j * 2 * math.pi * k_x * w_h
        w_x = torch.fft.ifft2(w_x_h).real

        #Partial y of vorticity
        w_y_h = 1j * 2 * math.pi * k_y * w_h
        w_y = torch.fft.ifft2(w_y_h).real

        #Non-linear term (u.grad(w)): compute in physical space then back to Fourier space
        F_h = torch.fft.fft2(q*w_x + v*w_y)
        dealias = dealias.to(dtype=F_h.dtype, device=F_h.device)

        #Dealias
        F_h = dealias * F_h

        #Cranck-Nicholson update
        numerator = -delta_t * F_h + delta_t * f_h + (1.0 - 0.5 * delta_t * visc * lap) * w_h
        denominator = 1.0 + 0.5 * delta_t * visc * lap
        w_h = numerator / denominator


        #Update real time (used only for recording)
        t += delta_t

        if (j+1) % record_time == 0:
            #Solution in physical space
            w = torch.fft.ifft2(w_h).real

            #Record solution and time
            sol[...,c] = w
            sol_t[c] = t

            c += 1


    return sol, sol_t


device = torch.device('cuda')

#Resolution
s = 256
sub = 1

#Number of solutions to generate
N = 500

#Set up 2d GRF with covariance parameters
GRF = GaussianRF(2, s, alpha=2.5, tau=7, device=device)

#Forcing function: 0.1*(sin(2pi(x+y)) + cos(2pi(x+y)))
t = torch.linspace(0, 1, s+1, device=device)
t = t[0:-1]

X, Y = torch.meshgrid(t, t, indexing='ij')
f = 0.1*(torch.sin(2*math.pi*(X + Y)) + torch.cos(2*math.pi*(X + Y)))

#Number of snapshots from solution
record_steps = 100

#Inputs
a = torch.zeros(N, s, s)
#Solutions
u = torch.zeros(N, s, s, record_steps)

#Solve equations in batches (order of magnitude speed-up)

#Batch size
bsize = 20

c = 0
t0 =default_timer()
for j in range(N//bsize):

    #Sample random feilds
    w0 = GRF.sample(bsize)

    #Solve NS
    sol, sol_t = navier_stokes_2d(w0, f, 1e-3, 50.0, 1e-4, record_steps)

    a[c:(c+bsize),...] = w0
    u[c:(c+bsize),...] = sol

    c += bsize
    t1 = default_timer()
    print(j, c, t1-t0)

with h5py.File('ns_data.h5', 'w') as hf:
    hf.create_dataset('a', data=a.cpu().numpy(), compression='gzip')
    hf.create_dataset('u', data=u.cpu().numpy(), compression='gzip')
    hf.create_dataset('t', data=sol_t.cpu().numpy())

# %% [markdown]
# #### Visualization

# %%
#Animated Visualization for a sample in time
# %matplotlib qt
sample_idx = 0

u_sample = u[sample_idx]
fig, ax = plt.subplots()
im = ax.imshow(u_sample[..., 0].cpu(), cmap='seismic', vmin=-1, vmax=1)  # adjust vmin/vmax if needed
ax.set_title("Time step 0")
plt.colorbar(im, ax=ax)

# Animation loop
for i in range(u_sample.shape[-1]):
    im.set_data(u_sample[..., i].cpu())
    ax.set_title(f"Time step {i}")
    plt.pause(0.05)

plt.show()

# %%
#Saving animation as figure

sample_idx = 100

# Get vorticity for this sample
u_sample = u[sample_idx].cpu()  # shape: (s, s, record_steps)

# Set up figure and axis
fig, ax = plt.subplots()
vmin = u_sample.min().item()
vmax = u_sample.max().item()

im = ax.imshow(u_sample[..., 0], cmap='seismic', vmin=-1, vmax=1)
ax.set_title("Time step 0")
plt.colorbar(im, ax=ax)

# Update function
def update(i):
    im.set_data(u_sample[..., i])
    ax.set_title(f"Time step {i}")
    return [im]

# Create animation
ani = FuncAnimation(fig, update, frames=u_sample.shape[-1], interval=100)

# Save as GIF (requires ImageMagick or Pillow)
ani.save('vorticity_evolution.gif', writer='pillow', fps=20)
